# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %pip install tqdm

from tqdm import tqdm
tqdm.pandas()  # Integrasi tqdm dengan pandas
# Out:
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (4.67.1)

# %%
# !pip install google-play-scraper

import pandas as pd
import numpy as np
from google_play_scraper import app, reviews
import os
import nltk
from nltk.corpus import stopwords
from nltk.sentiment import SentimentIntensityAnalyzer
from google_play_scraper import app, Sort, reviews_all
# Out:
# Collecting google-play-scraper
#   Downloading google_play_scraper-1.2.7-py3-none-any.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 2.8 MB/s eta 0:00:00
# Downloading google_play_scraper-1.2.7-py3-none-any.whl (28 kB)
# Installing collected packages: google-play-scraper
# Successfully installed google-play-scraper-1.2.7

# %%
app_id = 'com.icon.pln123'
# Mengambil ulasan
reviews_data, _ = reviews(
    app_id,
    lang='id',
    country='id',
    count=10000
)

# Konversi ke DataFrame
reviews_df = pd.DataFrame(reviews_data)
reviews_df
# Out:
#                                   reviewId         userName  \
# 0     0450243b-135f-422c-b1e1-2a3d2aa6d14b  Pengguna Google
# 1     ba17c310-106a-4112-97f5-a135863a295f  Pengguna Google
# 2     ca2f6ea5-c6c4-45b9-812f-972d5f62a484  Pengguna Google
# 3     5b14b400-f703-4386-b2ad-88e579ab1631  Pengguna Google
# 4     73badab6-328a-4191-a3f2-e4eb8808cf5a  Pengguna Google
# ...                                    ...              ...
# 9995  492acbab-1ce9-4b90-acce-dd74221b06fe             Alif
# 9996  80cda322-53c7-4c5e-8997-143b7f912d22       Dina Nadin
# 9997  22829f5c-fb4e-44d2-bbc1-87aea082078e    Widji Santoso
# 9998  494d2956-f8c8-4d41-908e-4e54b7690abe       Faisalican
# 9999  ef8e3af3-3cab-47ff-bd31-6ed9e87b72a5       Nurul Aeni
#
#                                               userImage  \
# 0     https://play-lh.googleusercontent.com/EGemoI2N...
# 1     https://play-lh.googleusercontent.com/EGemoI2N...
# 2     https://play-lh.googleusercontent.com/EGemoI2N...
# 3     https://play-lh.googleusercontent.com/EGemoI2N...
# 4     https://play-lh.googleusercontent.com/EGemoI2N...
# ...                                                 ...
# 9995  https://play-lh.googleusercontent.com/a/ACg8oc...
# 9996  https://play-lh.googleusercontent.com/a/ACg8oc...
# 9997  https://play-lh.googleusercontent.com/a-/ALV-U...
# 9998  https://play-lh.googleusercontent.com/a-/ALV-U...
# 9999  https://play-lh.googleusercontent.com/a/ACg8oc...
#
#                                                 content  score  thumbsUpCount  \
# 0                                                 👍👍👍👍👍      5              0
# 1           sangat mempermudah penggunaan semoga sukses      5              0
# 2     Semoga dengan adanya aplikasi ini bisa lebih m...      5              0
# 3                              aplikasi bagus dan cepat      5              0
# 4                             amanah sangat mempermudah      5              0
# ...                                                 ...    ...            ...
# 9995               matur suwun aplikasi sangat membantu      5              0
# 9996                                               good      5              0
# 9997                               Joss pelayanan nya..      5              0
# 9998  aplikasinya sangat membantu, mempermudah kita,...      5              0
# 9999                      sangat membantu,, mempermudah      5              0
#
#      reviewCreatedVersion                  at  \
# 0                    None 2025-09-28 03:54:36
# 1                    None 2025-09-28 03:51:08
# 2                  5.2.74 2025-09-28 03:45:46
# 3                  5.2.74 2025-09-28 03:41:18
# 4                  5.2.74 2025-09-28 03:39:53
# ...                   ...                 ...
# 9995               5.2.74 2025-09-10 13:10:29
# 9996               5.2.74 2025-09-10 13:05:45
# 9997               5.2.74 2025-09-10 13:01:41
# 9998               5.2.74 2025-09-10 12:59:55
# 9999               5.2.74 2025-09-10 12:50:51
#
#                                            replyContent           repliedAt  \
# 0     Halo Kak Ahok, kami merasa terhormat telah men... 2025-09-28 04:14:49
# 1     Wah, makasih banyak ya Kak Suwarno. Admin past... 2025-09-28 04:11:42
# 2     Waw Kak. Tks Kak penilaiannya, semoga semakin ... 2025-09-03 06:37:53
# 3     Wah, makasih banyak Kak Atika Kapitan. Senang ... 2025-09-28 04:12:34
# 4     Terima kasih atas ulasan positif dan kepercaya... 2025-09-28 04:12:42
# ...                                                 ...                 ...
# 9995  Yuhu Kak Alif. Waah makasih ya buat feedback d... 2025-09-11 04:40:18
# 9996  Halo Kak Dina. Thank you bintang 5 nya ya. Kam... 2025-09-11 04:42:06
# 9997  Hai Kak Widji. Trims ya Kak untuk penilaiannya... 2025-09-11 04:43:49
# 9998  Waw Kak Faisalican. Makasi buat bintang 5 nya.... 2025-09-11 04:44:24
# 9999  Halo Kak Nurul. Tks yaa udah kasih bintang 5. ... 2025-09-11 04:45:00
#
#      appVersion
# 0          None
# 1          None
# 2        5.2.74
# 3        5.2.74
# 4        5.2.74
# ...         ...
# 9995     5.2.74
# 9996     5.2.74
# 9997     5.2.74
# 9998     5.2.74
# 9999     5.2.74
#
# [10000 rows x 11 columns]

# %%
# save to csv
reviews_df.to_csv('hasil_reviews_pln_mobile.csv', index=False)
